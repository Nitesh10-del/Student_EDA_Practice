# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nk424\OneDrive\Scans\Desktop\training\Sample_Data\insurance.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df.age,df.bought_insurance,marker='*',color='g')

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
print("shape of x_train",x_train.shape)
print("shape of x_test",x_test.shape)
# Out:
# shape of x_train (18, 1)
# shape of x_test (9, 1)

# %%
print("shape of y_train",y_train.shape)
print("shape of y_test",y_test.shape)
# Out:
# shape of y_train (18,)
# shape of y_test (9,)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
model.predict_proba(x_test) # returns the probablity of data points belongong to each class
# Out:
# array([[0.04567825, 0.95432175],
#        [0.80851063, 0.19148937],
#        [0.05197447, 0.94802553],
#        [0.86384632, 0.13615368],
#        [0.91610842, 0.08389158],
#        [0.82865307, 0.17134693],
#        [0.87903892, 0.12096108],
#        [0.07611236, 0.92388764],
#        [0.8470775 , 0.1529225 ]])

# %%
model.score(x_test,y_test)
# Out:
# 0.8888888888888888

# %%
x_test
# Out:
# array([[62],
#        [29],
#        [61],
#        [26],
#        [22],
#        [28],
#        [25],
#        [58],
#        [27]])

# %%
x_test[2]
# Out:
# array([61])

# %%
model.predict(x_test[2].reshape(1,-1))
# Out:
# array([1])

# %%
x_test[3]
# Out:
# array([26])

# %%
model.predict(x_test[3].reshape(1,-1))
# Out:
# array([0])
